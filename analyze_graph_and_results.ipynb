# %%
from seirsplus.models import *
from seirsplus.networks import *
from seirsplus.sim_loops import *
from seirsplus.utilities import *
import networkx as nx
import time
import matplotlib.pyplot as plt
import pickle
import numpy as np
from seirsplus.utilities import load_model, save_model, convert_percentage_to_scale
# from seirsplus.networks import prune_graph_per_age
plt.rcParams["figure.figsize"] = (12, 6)
import pandas as pd
import os
from scipy.interpolate import interp1d

# %%
vacc_data = pd.read_csv("../israel_data/vaccination_data_for_simulation.csv")

# %%
def get_cmap(n=20, map_str= 'hsv'):
    cmap = plt.get_cmap(map_str)
    colors = [cmap(i) for i in np.linspace(0, 1, n)]
    return colors

# %%
def moving_average(x, w):
    return np.convolve(x, np.ones(w), 'valid') / w

# %%
N = 10000
colors = get_cmap(30)
fig, ax = plt.subplots(1, 1)
fig1, ax1 = plt.subplots(1, 1)
times_for_sim = np.array([160, 173, 178, 185, 203, 207, 218, 219, 235, 247, 254, 261, 265, 276, 285, 290]) - 160
event = ['Minimum active cases', '5-6 back to school', '9-12 back to school',
             '7-8 back to school', 'British variant', '3rd lockdown',
             'schools close', 'Most cases new mutations', 'Closed airport',
             'back:1-4,work', 'airports semi open', 'back:5-6,11-12',
             'purim', 'back:restaurants,7-10', 'airports fully opened', 'normal']

time = numpy.load('g_third_lockdown/time_3rd_wave.npy')
active_cases = numpy.load('g_third_lockdown/active_cases_3rd_wave.npy')



subfolders = [f.path for f in os.scandir("g_third_lockdown/test_coeffs") if f.is_dir()]
data = {'model': [], 'input_config': [], 'relevant_data': []}
relevant_keys = ['airport', 'two_grades', 'pre_school', 'restaurants', 'work', 'starting_prec', 'holiday', 'quarantine_per', 'normal']
plt.figure()
for i, s in enumerate(subfolders):
    max_time = 130
    data['model'].append(load_model(f"{s}/model_out"))
    with open(f"{s}/input_config.pickle", 'rb') as handle:
        input_data = pickle.load(handle)
    relevant_input = [input_data[k] for k in relevant_keys]
    data['input_config'].append(input_data)
    
    time_ind = np.where(data['model'][i].tseries<=max_time)[0]
    
    
    model_data = (((data['model'][i].numI_sym+data['model'][i].numH)*9e6)/N)[time_ind]
    time_to_plot = data['model'][i].tseries[time_ind]
    
    smooth_model = moving_average(model_data, np.ceil(data['model'][i].numI_sym.shape[0] / 100).astype(int))
    smooth_time = moving_average(time_to_plot, np.ceil(data['model'][i].numI_sym.shape[0] / 100).astype(int))
    
    max_time = np.min([max_time, smooth_time.max()-1])
    min_time = smooth_time.min()+1
    time_scale = np.arange(min_time, max_time, 1)
    f_real_data = interp1d(time, active_cases)
    real_data = f_real_data(time_scale)
    f_model = interp1d(smooth_time, smooth_model)
    model_out = f_model(time_scale)
    ax.plot(time_scale, model_out, color=colors[i], label=f'model:{i}')
    for t, e in zip(times_for_sim, event):
        ax.axvline(int(t), 0, 1, c='k')
        ax.text(int(t)+0.1, 0, str(e), rotation=90)
    ax.plot(time_scale, real_data, '-k', marker='.')
    model_diff = np.linalg.norm((model_out - real_data)/time_to_plot.size)
    relevant_input.append(model_diff)
    relevant_input.append(s)
    
    #                   [0-9,  10-19,20-29,30-39,40-49,50-59,60-69,70-79, 80+]
    age_dist = np.array([0.197,0.181,0.135,0.123,0.121,0.084,0.081,0.050,0.028])
    x_k = []
    y_m = []
    for num, key in enumerate(data['model'][i].nodeGroupData.keys()):
        num_nodes = data['model'][i].nodeGroupData[key]['nodes'].size
        per_pop = num_nodes/N
        mean_age = np.mean(data['model'][i].nodeGroupData[key]['numPositive']/(data['model'][i].numPositive+1e-5))
        x_k.append(key)
        y_m.append((mean_age/per_pop).astype(float))
#         print(f"age:{key}, per real:{age_dist[num]}, per sim:{per_pop}")
#         y_m.append((mean_age/age_dist[num]).astype(float))
#     ax1.scatter(x_k,y_m, color=colors[i], marker='x')
    ax1.bar(x_k,y_m, color=colors[i], alpha=0.3)
#     relevant_input.append(np.array(y_m))
    data['relevant_data'].append(relevant_input)
ax.legend()
relevant_keys.append('model_diff')
relevant_keys.append('folder_num')
ax1.grid()
ax.grid()

input_df = pd.DataFrame(np.array(data['relevant_data']), columns = relevant_keys)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-32-acb962592063> in <module>
#      10              'purim', 'back:restaurants,7-10', 'airports fully opened', 'normal']
#      11
# ---> 12 time = numpy.load('g_third_lockdown/time_3rd_wave.npy')
#      13 active_cases = numpy.load('g_third_lockdown/active_cases_3rd_wave.npy')
#      14
#
# ~/opt/anaconda3/envs/py38_env/lib/python3.8/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     415             own_fid = False
#     416         else:
# --> 417             fid = stack.enter_context(open(os_fspath(file), "rb"))
#     418             own_fid = True
#     419
#
# FileNotFoundError: [Errno 2] No such file or directory: 'g_third_lockdown/time_3rd_wave.npy'

# %%
input_df
# Out:
#    airport two_grades pre_school restaurants work starting_prec holiday  \
# 0        2          7         13          11    6            58       9
# 1        0          7         12          12   13            56       5
# 2        3         11         11          12    7            78       2
# 3        5          7         10          12    7            69       5
# 4        4         12          6          13   14            75       5
# 5        5         10         14           7   13            55       7
# 6        5         11          8          10    6            77       2
# 7        4         13         13           6    9            73       0
# 8        4          8          9          14   12            71       5
# 9        0          6          5           9    7            73       4
# 10       2          9         11           8   12            73       7
# 11       2          9         14          14   11            54       4
# 12       2         10         13          13   14            79       7
# 13       0         12          6           6    9            64       0
# 14       3          8         10          11   12            59       8
# 15       0         13          9          13    8            50       5
# 16       0         13         12           7   13            58       3
# 17       5          7          5          11    9            60       0
# 18       3          6         11          10    5            57       7
# 19       0         14          8          14    8            58       4
# 20       5         11          7           8   11            64       2
# 21       1         12         14           8    9            79       8
# 22       2         14          5          12   11            75       3
# 23       5          7          9           5    9            66       7
# 24       5          7         11           7   12            78       1
# 25       4          9          6           9    8            51       1
# 26       3         12          9          14    8            57       4
# 27       1          8         11           7    7            55       2
#
#    quarantine_per normal          model_diff                       folder_num
# 0              88     19   358.4451292195539  g_third_lockdown/test_coeffs/20
# 1              87      6  334.68186064342285  g_third_lockdown/test_coeffs/18
# 2              93     18   5000.165926658592  g_third_lockdown/test_coeffs/27
# 3              92     16   164.5861521296376   g_third_lockdown/test_coeffs/9
# 4              93     13  36.231443132640955   g_third_lockdown/test_coeffs/0
# 5              88     18   91.34466993404844  g_third_lockdown/test_coeffs/11
# 6              88      4  19.706268615716066   g_third_lockdown/test_coeffs/7
# 7              90      6  13.596321837477243  g_third_lockdown/test_coeffs/16
# 8              85     14   25.57229764566424   g_third_lockdown/test_coeffs/6
# 9              90      3  215.17853950705575  g_third_lockdown/test_coeffs/17
# 10             87      3  111.07335889070508   g_third_lockdown/test_coeffs/1
# 11             92     18   2090.550170003807  g_third_lockdown/test_coeffs/10
# 12             86     11  13.539718659512804  g_third_lockdown/test_coeffs/19
# 13             87      4   11.24376254058394  g_third_lockdown/test_coeffs/26
# 14             88     13   267.0851938956761   g_third_lockdown/test_coeffs/8
# 15             87     16  30.730849394359865  g_third_lockdown/test_coeffs/21
# 16             86      3   34.92412174870338  g_third_lockdown/test_coeffs/24
# 17             91      1  14.075279514001291  g_third_lockdown/test_coeffs/23
# 18             89     11  21.368431244036053   g_third_lockdown/test_coeffs/4
# 19             89      5   264.4942501360185  g_third_lockdown/test_coeffs/15
# 20             86      1   22.75861584740277   g_third_lockdown/test_coeffs/3
# 21             86      7   19.22924793361712  g_third_lockdown/test_coeffs/12
# 22             86      2    18.9509038465529   g_third_lockdown/test_coeffs/2
# 23             94      8   367.0648108284646  g_third_lockdown/test_coeffs/13
# 24             90     17   7.186901641716301   g_third_lockdown/test_coeffs/5
# 25             90     12    12.5669609982805  g_third_lockdown/test_coeffs/14
# 26             89     15  19.506081272838177  g_third_lockdown/test_coeffs/22
# 27             85     14  39.658938422585024  g_third_lockdown/test_coeffs/25

# %%
# [(k,data['input_config'][23][k]) for k in data['input_config'][23].keys() if k not in ['beta_values', 'beta_q_values','Q_GLOBALINTXN','P_GLOBALINTXN', 'checkpoint_times']]

# %%
data['model'][21].numE[0] * 9*10**6 / N, (data['model'][21].numI_sym[0] * 9*10**6 / N ), 900/990
# Out:
# (8100.0, 9900.0, 0.9090909090909091)

# %%
# self.S = 1
# self.E = 2
# self.I_pre = 3
# self.I_sym = 4
# self.I_asym = 5
# self.H = 6
# self.R = 7
# self.F = 8
# self.Q_S = 11
# self.Q_E = 12
# self.Q_pre = 13
# self.Q_sym = 14
# self.Q_asym = 15
# self.Q_R = 17

# %%
# time_line = [5, 30, 60, 90, 115, 120, 137, 150, 160]
# events = ['hofesh gadol', 'close <50,20', 'close work', 'schools back', 'full seger', 'maximum-72k',
#          'kindergarden back', 'grades 1-4 back', 'minimum-8000']
model_2 = load_model(f"g_third_lockdown/test_coeffs/5/model_out")
times_for_sim = np.array([160, 173, 178, 185, 203, 207, 218, 219, 235, 247, 254, 261, 265, 276, 285, 290]) - 160
event = ['Minimum active cases', '5-6 back to school', '9-12 back to school',
         '7-8 back to school', 'British variant', '3rd lockdown',
         'schools close', 'Most cases new mutations', 'Closed airport',
         'back:1-4,work', 'airports semi open', 'back:5-6,11-12',
         'purim', 'back:restaurants,7-10', 'airports fully opened', 'normal']

plt.plot(model_2.tseries, ((model_2.numI_sym+model_2.numH)*9e6)/N)
for time, event in zip(times_for_sim, event):
    plt.axvline(int(time), 0, 1, c='k')
    plt.text(int(time)+0.1, 0, str(event), rotation=90)

time = numpy.load('g_third_lockdown/time_3rd_wave.npy')
active_casese = numpy.load('g_third_lockdown/active_cases_3rd_wave.npy')
plt.plot(time, active_casese, '-r')
plt.show()

age_dist = np.array([0.197,0.181,0.135,0.123,0.121,0.084,0.081,0.050,0.028])
for num, key in enumerate(model_2.nodeGroupData.keys()):
    mean_age = np.mean(model_2.nodeGroupData[key]['numPositive']/(model_2.numPositive+1e-5))
    plt.bar(key,(mean_age/age_dist[num]).astype(float))
plt.show()

fig, ax = model_2.figure_infections(combine_Q_infected=False)
plt.show()
model_2.numE /model_2.numI_sym
# Out:
# <ipython-input-15-39953f3a0e1d>:30: RuntimeWarning: divide by zero encountered in true_divide
#   model_2.numE /model_2.numI_sym
# array([0.09090909, 0.1       , 0.        , ..., 2.25      , 3.        ,
#        2.66666667])

# %%
N = 10000
colors = get_cmap(30)
fig, ax = plt.subplots(1, 1)
fig1, ax1 = plt.subplots(1, 1)
times_for_sim = np.array([160, 173, 178, 185, 203, 207, 218, 219, 235, 247, 254, 261, 265, 276, 285, 290]) - 160
event = ['Minimum active cases', '5-6 back to school', '9-12 back to school',
             '7-8 back to school', 'British variant', '3rd lockdown',
             'schools close', 'Most cases new mutations', 'Closed airport',
             'back:1-4,work', 'airports semi open', 'back:5-6,11-12',
             'purim', 'back:restaurants,7-10', 'airports fully opened', 'normal']

time = numpy.load('g_third_lockdown/time_3rd_wave.npy')
active_cases = numpy.load('g_third_lockdown/active_cases_3rd_wave.npy')



subfolders = [f.path for f in os.scandir("g_third_lockdown/test_alpha") if f.is_dir()]
data = {'model': [], 'input_config': [], 'relevant_data': []}
relevant_keys = ['airport', 'two_grades', 'pre_school', 'restaurants', 'work', 'starting_prec', 'holiday', 'quarantine_per', 'normal']
plt.figure()
for i, s in enumerate(subfolders):
    max_time = 130
    data['model'].append(load_model(f"{s}/model_out"))
    with open(f"{s}/input_config.pickle", 'rb') as handle:
        input_data = pickle.load(handle)
    relevant_input = [input_data[k] for k in relevant_keys]
    data['input_config'].append(input_data)
    
    time_ind = np.where(data['model'][i].tseries<=max_time)[0]
    
    
    model_data = (((data['model'][i].numI_sym+data['model'][i].numH)*9e6)/N)[time_ind]
    time_to_plot = data['model'][i].tseries[time_ind]
    
    smooth_model = moving_average(model_data, np.ceil(data['model'][i].numI_sym.shape[0] / 100).astype(int))
    smooth_time = moving_average(time_to_plot, np.ceil(data['model'][i].numI_sym.shape[0] / 100).astype(int))
    
    max_time = np.min([max_time, smooth_time.max()-1])
    min_time = smooth_time.min()+1
    time_scale = np.arange(min_time, max_time, 1)
    f_real_data = interp1d(time, active_cases)
    real_data = f_real_data(time_scale)
    f_model = interp1d(smooth_time, smooth_model)
    model_out = f_model(time_scale)
    ax.plot(time_scale, model_out, color=colors[i], label=f'model:{i}')
    for t, e in zip(times_for_sim, event):
        ax.axvline(int(t), 0, 1, c='k')
        ax.text(int(t)+0.1, 0, str(e), rotation=90)
    ax.plot(time_scale, real_data, '-k', marker='.')
    model_diff = np.linalg.norm((model_out - real_data)/time_to_plot.size)
    relevant_input.append(model_diff)
    relevant_input.append(s)
    data['relevant_data'].append(relevant_input)
    #                   [0-9,  10-19,20-29,30-39,40-49,50-59,60-69,70-79, 80+]
    age_dist = np.array([0.197,0.181,0.135,0.123,0.121,0.084,0.081,0.050,0.028])
    x_k = []
    y_m = []
    for num, key in enumerate(data['model'][i].nodeGroupData.keys()):
        num_nodes = data['model'][i].nodeGroupData[key]['nodes'].size
        per_pop = num_nodes/N
        mean_age = np.mean(data['model'][i].nodeGroupData[key]['numPositive']/(data['model'][i].numPositive+1e-5))
        x_k.append(key)
        y_m.append((mean_age/per_pop).astype(float))
#         print(f"age:{key}, per real:{age_dist[num]}, per sim:{per_pop}")
#         y_m.append((mean_age/age_dist[num]).astype(float))
#     ax1.scatter(x_k,y_m, color=colors[i], marker='x')
    ax1.bar(x_k,y_m, color=colors[i], alpha=0.3)
ax.legend()
relevant_keys.append('model_diff')
relevant_keys.append('folder_num')
ax1.grid()
ax.grid()

input_df = pd.DataFrame(np.array(data['relevant_data']), columns = relevant_keys)

# %%
alone_parma = 0.3
couples_without_kids_param = 0.85
kids_left_house_p = 0.36
old_kids = 0.3
two_kids_young = 0.28
two_kids_old = 0.032

three_kids_young = 0.37
three_kids_old = 0.1

four_kids_young = 0.37
four_kids_old = 0.1

number_of_people_each_household = [1, 4, 4, 2, 2, 3, 3, 4, 5, 8]
households_data = \
    {
    'alone': {0.05 * 0.9: [0, 0, alone_parma/2, alone_parma/2, 0, 0 * (1 - alone_parma) / 8,3 * (1 - alone_parma) / 8,2 * (1 - alone_parma) / 8, 3 * (1 - alone_parma) / 8]},
    'students_app': {0.05 * 0.1: [0, 0.2, 0.8, 0, 0, 0, 0, 0, 0]},
    'soldier': {0.015: [0.0, 0.8, 0.2, 0, 0, 0, 0, 0, 0]},
    'couples_without_kids': {0.935 * 0.28 * 0.25: [0, 0, couples_without_kids_param, 1 - couples_without_kids_param, 0, 0, 0, 0, 0]},
    'couples_kids_left_the_house': {0.935 * 0.28 * 0.75: [0, 0, 0, 0, 0, kids_left_house_p, 16 * (1 - kids_left_house_p) / 30,10 * (1 - kids_left_house_p) / 30, 4 * (1 - kids_left_house_p) / 30]},
    'couples_with_one_young_kid': {0.935 * 0.18 * 0.9: [0.7, 0.3, 0.5, 0.5, 0, 0, 0, 0, 0]},
    'couples_with_one_old_kid': {0.935 * 0.18 * 0.1: [0.0, 1.0, 0.0, old_kids, 1 - old_kids, 0, 0, 0, 0]},
    'couples_with_two_kid': {0.935 * 0.19: [0.5, 0.45, 0.05, two_kids_young, 1 - two_kids_young - two_kids_old, two_kids_old, 0, 0, 0]},
    'couples_with_three_kid': {0.935 * 0.17: [0.5, 0.45, 0.05, three_kids_young, 1 - three_kids_old - three_kids_young, three_kids_old, 0,0, 0]},
    'couples_with_four_kid_pluse': {0.935 * 0.18: [0.5, 0.45, 0.05, three_kids_young, 1 - three_kids_old - three_kids_young, three_kids_old, 0,0, 0]},
}

# %%
# list(model_2.X[model_2.nodeGroupData['0-9']['nodes']])

# %%
plt.plot(model_2.tseries, model_2.numH * 9*10**6/N, marker='.')
plt.grid()

# %%
data_pol
# Out:
#     Unnamed: 0                                               name  \
# 0            0                                   תחילת הסגר הרשמי
# 1            1                                           פסח בסגר
# 2            2                   מקומות הבילוי והפנאי נפתחים מחדש
# 3            3                                חזרה חלקית ללימודים
# 4            4              חידוש התפילות והפעילות בבריכות השחייה
# 5            5                               הקניונים נפתחים מחדש
# 6            6                             גני הילדים נפתחים מחדש
# 7            7                         חזרה ללימודים, ללא קפסולות
# 8            8               חובת המסכות מבוטלת זמנית בשל שרב כבד
# 9            9          המסעדות, המועדונים ובתי המלון נפתחים מחדש
# 10          10               אולמות אירועים ותיאטראות נפתחים מחדש
# 11          11               שוב סוגרים: הגבלת התקהלויות ל-20 איש
# 12          12                                 הקפאת המשך המגבלות
# 13          13                                הישיבות נפתחות מחדש
# 14          14                               בתי הספר נפתחים מחדש
# 15          15                             מתווה הרמזור יוצא לדרך
# 16          16                         ראש השנה – תחילת הסגר השני
# 17          17  שלב ראשון של היציאה מהסגר: פתיחת המסגרות לגיל הרך
# 18          18  מוסדות החינוך החרדיים נפתחים בניגוד להנחיות הק...
# 19          19              שלב שני: כיתות א'-ד' חוזרות לבתי הספר
# 20          20                       הגדלת הקנסות על הפרת ההגבלות
# 21          21                                חנויות הרחוב נפתחות
# 22          22         חברת פייזר מודיעה כי החיסון שלה יעיל ב-90%
# 23          23      חברת מודרנה מודיעה כי החיסון שלה יעיל ב-94.5%
# 24          24                       כיתות ה'-ו' חוזרות לבתי הספר
# 25          25                       תוכנית פיילוט לפתיחת קניונים
# 26          26                      כיתות י'-י"ב חוזרות לבתי הספר
# 27          27                        כיתות ז'-ט' חוזרות ללימודים
# 28          28  החיסון של פייזר מקבל את אישור מנהל המזון והתרו...
# 29          29  התלמידים ביישובים אדומים וכתומים לא חוזרים ללי...
# 30          30                   השלבים הראשונים של החיסון בישראל
# 31          31                      החוזרים מחו"ל מפונים למלוניות
# 32          32               המוטציה הבריטית המידבקת מתגלה בישראל
# 33          33  ישראל מובילה בעולם בחיסונים ביחס לגודל האוכלוסייה
# 34          34                                  תחילת הסגר השלישי
# 35          35  ישראל חותמת עם חברת פייזר על הסכם להגברת מאמצי...
# 36          36          הארכת הסגר השלישי והחמרה ניכרת של ההגבלות
# 37          37        המוטציה הדרום-אפריקאית המידבקת מתגלה בישראל
# 38          38                  מורים ובני 55 ומעלה יכולים להתחסן
# 39          39                        הארכת הסגר השלישי ב-10 ימים
# 40          40                         בני 40 ומעלה יכולים להתחסן
# 41          41         מעל רבע מהאוכלוסייה קיבלו את החיסון הראשון
# 42          42                            בני 16–18 יכולים להתחסן
# 43          43                          עצירת הטיסות לישראל וממנה
# 44          44              חצי ממקרי הקורונה הם מהמוטציה הבריטית
# 45          45          כלל האוכלוסייה מגיל 16 ומעלה יכולה להתחסן
# 46          46                      פתיחה מחדש של המשק: שלב ראשון
# 47          47     רבע מהאוכלוסייה קיבלו את המנה השנייה של החיסון
# 48          48                              השמיים מתחילים להיפתח
# 49          49                        פתיחה מחדש של המשק: שלב שני
# 50          50                   החיסון של פייזר יעיל ביותר מ-95%
# 51          51                                          סגר פורים
# 52          52                      מחלימים מקורונה יכולים להתחסן
# 53          53                          פתיחה מחדש של המשק: שלב 3
# 54          54                 אישור כניסת טיסות נכנסות מכל העולם
# 55          55                          פתיחה מחדש של המשק: שלב 4
# 56          56        בג"צ מכריע: יותר נוסעים יוכלו להיכנס לישראל
# 57          57                                  אין אזורים אדומים
#
#                                           description  tagsCsv        time  \
# 0   מגבלת מרחק של 100 מטרים מהבית, פעילויות חיוניו...      NaN  2020-03-19
# 1   פסח בבית (7–16 באפריל) בחברת המשפחה הגרעינית ב...      NaN  2020-04-07
# 2   צמצום ההגבלות, פתיחה מחדש של חנויות הרחוב, פתי...      NaN  2020-04-24
# 3   תלמידי כיתות א'-ג', י"א-י"ב חוזרים ללמוד בקפסו...      NaN  2020-05-03
# 4   פתיחה של ספריות, מלונות, פארקים ציבוריים, גני ...      NaN  2020-05-04
# 5       שיעור הבדיקות החיוביות הממוצע ל-7 ימים: 0.75%      NaN  2020-05-07
# 6       שיעור הבדיקות החיוביות הממוצע ל-7 ימים: 0.60%      NaN  2020-05-10
# 7   כולם חוזרים ללימודים, הקפסולות מבוטלות (חזרה ל...      NaN  2020-05-17
# 8   חובת המסכות בחוץ ובכיתות מבוטלת עקב שרב כבד מ-...      NaN  2020-05-19
# 9   פתיחה מחודשת של מסעדות, מועדונים, בתי מלון, בר...      NaN  2020-05-27
# 10  פתיחה של אולמות האירועים והתיאטראות עד 250 איש...      NaN  2020-06-14
# 11  ההתקהלויות מוגבלות ל-20 איש; בתי הכנסת מוגבלים...      NaN  2020-07-06
# 12  נסיגה מן התוכנית להרחיב את המגבלות בעקבות לחץ ...      NaN  2020-07-17
# 13  הישיבות החרדיות נפתחות מחדש, כולל הישיבות הקטנ...      NaN  2020-08-21
# 14  בתי הספר נפתחים עם תחילת שנת הלימודים החדשה.\n...      NaN  2020-09-01
# 15  מגבלות מקומיות בהתאם לרמת התחלואה בכל רשות מקו...      NaN  2020-09-06
# 16  בראש השנה מוטל סגר מלא: סגירת בתי הספר, סגירת ...      NaN  2020-09-18
# 17  פתיחת המעונות והגנים (גם בערים האדומות); פתיחת...      NaN  2020-10-18
# 18  הישיבות והחדרים נפתחים, אך בתי הספר הממלכתיים ...      NaN  2020-10-18
# 19  כיתות א'-ד' חוזרות ללימודים ל-4 ימים בשבוע לפח...      NaN  2020-11-01
# 20  הקנס לעסקים גדל מ-5,000 שקלים ל-10,000 שקלים; ...      NaN  2020-11-02
# 21  החנויות בקניונים והשווקים נשארים סגורים.\n\nשי...      NaN  2020-11-08
# 22  חברת פייזר מודיעה שבניסוי שערכה נמצא כי החיסון...      NaN  2020-11-09
# 23  חברת מודרנה מודיעה שבניסוי שלב 3 שערכה נמצא כי...      NaN  2020-11-16
# 24  כיתות ה'-ו' חוזרות ללמידה פיזית בכיתות ל-3 ימי...      NaN  2020-11-24
# 25  חמישה עשר קניונים נפתחים כחלק מתוכנית פיילוט ש...      NaN  2020-11-27
# 26  כיתות י'-י"ב חוזרות ללמידה פיזית בכיתות ליומיי...      NaN  2020-11-29
# 27  כיתות ז'-ט' חוזרות ללמידה פיזית למשך יומיים בש...      NaN  2020-12-06
# 28  החיסון של פייזר מקבל את אישור מנהל המזון והתרו...      NaN  2020-12-11
# 29  תלמידי כיתות ה'-י"ב לא חוזרים ללמידה פיזית לאח...      NaN  2020-12-20
# 30  הזכאים לסבב החיסונים הראשון הם אנשי הצוותים הר...      NaN  2020-12-20
# 31  נוסעים החוזרים מחו"ל נדרשים להיכנס לבידוד במלו...      NaN  2020-12-23
# 32  ארבעה מקרים של המוטציה הבריטית המידבקת מתגלים ...      NaN  2020-12-23
# 33      שיעור הבדיקות החיוביות הממוצע ל-7 ימים: 4.00%      NaN  2020-12-23
# 34  בשעה 17:00 נכנס לתוקף סגר בן שבועיים, אך הציבו...      NaN  2020-12-27
# 35  על פי ההסכם, פייזר תאיץ את קצב משלוחי החיסונים...      NaN  2021-01-07
# 36  סגר נוקשה יותר בן שבועיים נכנס לתוקף בחצות. הה...      NaN  2021-01-08
# 37  ארבעה מקרים של המוטציה הדרום-אפריקאית המידבקת ...      NaN  2021-01-09
# 38  הזכאות לקבלת חיסון מתרחבת לצוותי הוראה ולבני 5...      NaN  2021-01-12
# 39  מתקבלת החלטה על הארכת הסגר השלישי עד 31 בינואר...      NaN  2021-01-19
# 40  הזכאות לקבלת חיסון מתרחבת לבני 40 ומעלה.\n\nשי...      NaN  2021-01-19
# 41  יותר מ-רבע מאוכלוסיית ישראל קיבלו את המנה הראש...      NaN  2021-01-19
# 42  הזכאות לקבלת חיסון מתרחבת לבני 16–18, כדי להקל...      NaN  2021-01-23
# 43  הטיסות הנכנסות והיוצאות מוקפאות עד 31 בינואר, ...      NaN  2021-01-25
# 44  המוטציה הבריטית אחראית לכ-50% ממקרי הקורונה, 4...      NaN  2021-01-25
# 45  בעקבות ירידה חדה במספר המתחסנים ביום בתחילת פב...      NaN  2021-02-04
# 46  הגבלות התנועה הוסרו, עובדים במשרות שאינן במגע ...      NaN  2021-02-07
# 47  יותר מ-25% מאוכלוסיית ישראל קיבלו את המנה השני...      NaN  2021-02-10
# 48  מותרת כניסה של עד אלפיים איש מדי יום, מדיניות ...      NaN  2021-02-14
# 49  תלמידי כיתות ה'-ו', י"א-י"ב, ברשויות ירוקות, צ...      NaN  2021-02-21
# 50  יעילות החיסון מפני הפצת המחלה כשבוע לאחר קבלת ...      NaN  2021-02-22
# 51  הוכרז על סגר בין השעות 20:30 -5:00 עד לסיום חו...      NaN  2021-02-25
# 52  חולים בקורונה שהחלימו לפני יותר משלושה חודשים ...      NaN  2021-03-02
# 53  מסעדות, בתי קפה, אולמות אירועים, אירועי ספורט ...      NaN  2021-03-07
# 54  התרה של נחיתת מטוסים מכל היעדים.\n\nשיעור הבדי...      NaN  2021-03-16
# 55  הסרת מגבלות גודל מפעילויות חינוך וטיולים של בת...      NaN  2021-03-21
# 56  בג"צ מבטל את הגבלת הכניסה היומית של 3,000 איש ...      NaN  2021-03-21
# 57  משרד הבריאות הודיע כי לראשונה מאז הנהגת שיטת ה...      NaN  2021-03-30
#
#     group
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# 15    NaN
# 16    NaN
# 17    NaN
# 18    NaN
# 19    NaN
# 20    NaN
# 21    NaN
# 22    NaN
# 23    NaN
# 24    NaN
# 25    NaN
# 26    NaN
# 27    NaN
# 28    NaN
# 29    NaN
# 30    NaN
# 31    NaN
# 32    NaN
# 33    NaN
# 34    NaN
# 35    NaN
# 36    NaN
# 37    NaN
# 38    NaN
# 39    NaN
# 40    NaN
# 41    NaN
# 42    NaN
# 43    NaN
# 44    NaN
# 45    NaN
# 46    NaN
# 47    NaN
# 48    NaN
# 49    NaN
# 50    NaN
# 51    NaN
# 52    NaN
# 53    NaN
# 54    NaN
# 55    NaN
# 56    NaN
# 57    NaN
